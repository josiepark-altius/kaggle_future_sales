# %%
import os
os.chdir('../')

from config_load import *

# %%
from src.models.NN_methods import LSTMModel
# Out:
# Using TensorFlow backend.

# %%
from src.utils.load_save_data import load_static_files

# %%
static_files = load_static_files()

# %%
train = static_files['TRAIN_DATA']

# %%
test = static_files['TEST_DATA']

# %%
model = LSTMModel(config)

# %%
model.main(train, test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-8bb89c8f33c1> in <module>
# ----> 1 model.main(train, test)
#
# ~\OneDrive - Altius\Documents\projects\future_sales\src\models\NN_methods.py in main(self, train, test)
#      82
#      83     def main(self, train, test):
# ---> 84         self.prepare_data(train, test)
#      85         self.build()
#      86         self.fit()
#
# ~\OneDrive - Altius\Documents\projects\future_sales\src\models\NN_methods.py in prepare_data(self, train, test)
#      32
#      33         self.scaler = MinMaxScaler()
# ---> 34         self.scaler.fit(train['item_cnt_day'].reshape(1,-1))
#      35         train['scaled_item_cnt_day'] = self.scaler.transform(train['item_cnt_day'.reshape(1,-1)])
#      36         test['scaled_item_cnt_day'] = self.scaler.transform(test['item_cnt_day'].reshape(1,-1))
#
# ...
